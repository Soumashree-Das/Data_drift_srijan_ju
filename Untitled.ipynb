# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
#!pip install openpyxl

# %%
data = pd.read_excel('Dataset.xlsx')
data.head()
# Out:
#   District Name  Year        Date Time of Day  Number of vehicles involved  \
# 0   Chitradurga  2022  13-01-2022     Evening                            4
# 1    Ramanagara  2019  20-07-2019       Night                            3
# 2    Ramanagara  2017  01-03-2017       Night                            3
# 3      Bagalkot  2019  18-04-2019     Evening                            2
# 4        Hassan  2020  03-08-2020       Night                            2
#
#    Number of Casualties Accident_Classification   Accident_Spot Urban / Rural  \
# 0                    10          Road Accidents     Narrow road         Urban
# 1                    10          Road Accidents  Not Applicable         Urban
# 2                    10          Road Accidents           Other         Rural
# 3                    10          Not Applicable          Circle         Urban
# 4                    10          Road Accidents     Cross roads         Rural
#
#                 Accident Location           Cause Accident Severity  \
# 0                Residential area  Not Applicable             Fatal
# 1                   Near Bus stop  Not Applicable             Fatal
# 2                       Open area  Not Applicable             Fatal
# 3             Near office complex     Human Error             Fatal
# 4  Near a factory industrial area  Not Applicable             Fatal
#
#    Junction Control     Road_Character               Road_Type  \
# 0  No signal lights             Others  Highways & Expressways
# 1    Not Applicable     Not Applicable  Highways & Expressways
# 2      Uncontrolled             Others  Highways & Expressways
# 3        Controlled     Not Applicable  Highways & Expressways
# 4      Uncontrolled  Straight and flat  Highways & Expressways
#
#      Surface_Type Surface_Condition            Road_Condition  \
# 0    Bitumen(Tar)               Dry  No influence on accident
# 1  Not Applicable               Wet  No influence on accident
# 2    Bitumen(Tar)               Dry  No influence on accident
# 3    Bitumen(Tar)               Wet  No influence on accident
# 4        Concrete               Wet  No influence on accident
#
#   Weather Condition Lane_Type
# 0             Clear       NaN
# 1      Rain / Windy       NaN
# 2             Clear       NaN
# 3            Clear        NaN
# 4      Rain / Windy  DualLane

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301718 entries, 0 to 301717
# Data columns (total 20 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   District Name                301718 non-null  object
#  1   Year                         301718 non-null  int64
#  2   Date                         301718 non-null  object
#  3   Time of Day                  301718 non-null  object
#  4   Number of vehicles involved  301718 non-null  int64
#  5   Number of Casualties         301718 non-null  int64
#  6   Accident_Classification      301718 non-null  object
#  7   Accident_Spot                301718 non-null  object
#  8   Urban / Rural                301718 non-null  object
#  9   Accident Location            301718 non-null  object
#  10  Cause                        301718 non-null  object
#  11  Accident Severity            301718 non-null  object
#  12  Junction Control             301718 non-null  object
#  13  Road_Character               301718 non-null  object
#  14  Road_Type                    301718 non-null  object
#  15  Surface_Type                 301718 non-null  object
#  16  Surface_Condition            301718 non-null  object
#  17  Road_Condition               301718 non-null  object
#  18  Weather Condition            301718 non-null  object
#  19  Lane_Type                    62503 non-null   object
# dtypes: int64(3), object(17)
# memory usage: 46.0+ MB

# %%
data.isnull().sum()
# Out:
# District Name                       0
# Year                                0
# Date                                0
# Time of Day                         0
# Number of vehicles involved         0
# Number of Casualties                0
# Accident_Classification             0
# Accident_Spot                       0
# Urban / Rural                       0
# Accident Location                   0
# Cause                               0
# Accident Severity                   0
# Junction Control                    0
# Road_Character                      0
# Road_Type                           0
# Surface_Type                        0
# Surface_Condition                   0
# Road_Condition                      0
# Weather Condition                   0
# Lane_Type                      239215
# dtype: int64

# %%
print(data.isnull().values.any())
# Out:
# True

# %%
print(data[data.isnull().any(axis=1)])
# Out:
#         District Name  Year        Date Time of Day  \
# 0         Chitradurga  2022  13-01-2022     Evening
# 1          Ramanagara  2019  20-07-2019       Night
# 2          Ramanagara  2017  01-03-2017       Night
# 3            Bagalkot  2019  18-04-2019     Evening
# 5       Belagavi City  2022  16-04-2022     Evening
# ...               ...   ...         ...         ...
# 301709         Hassan  2022  06-04-2022       Night
# 301710         Hassan  2022  17-09-2022   Afternoon
# 301714         Hassan  2023  30-05-2023       Night
# 301715         Hassan  2023  12-07-2023     Evening
# 301716         Hassan  2023  25-02-2023     Evening
#
#         Number of vehicles involved  Number of Casualties  \
# 0                                 4                    10
# 1                                 3                    10
# 2                                 3                    10
# 3                                 2                    10
# 5                                 2                    10
# ...                             ...                   ...
# 301709                            1                     0
# 301710                            1                     0
# 301714                            1                     0
# 301715                            1                     0
# 301716                            1                     0
#
#        Accident_Classification   Accident_Spot Urban / Rural  \
# 0               Road Accidents     Narrow road         Urban
# 1               Road Accidents  Not Applicable         Urban
# 2               Road Accidents           Other         Rural
# 3               Not Applicable          Circle         Urban
# 5               Road Accidents  Not Applicable         Rural
# ...                        ...             ...           ...
# 301709          Road Accidents  Not Applicable         Urban
# 301710          Road Accidents  Not Applicable         Urban
# 301714          Road Accidents  Not Applicable         Rural
# 301715          Road Accidents  Not Applicable         Urban
# 301716          Road Accidents  Not Applicable         Rural
#
#              Accident Location           Cause Accident Severity  \
# 0             Residential area  Not Applicable             Fatal
# 1                Near Bus stop  Not Applicable             Fatal
# 2                    Open area  Not Applicable             Fatal
# 3          Near office complex     Human Error             Fatal
# 5             Residential area     Human Error             Fatal
# ...                        ...             ...               ...
# 301709  Near a religious place     Human Error         No Injury
# 301710               Open area     Human Error         No Injury
# 301714               Open area     Human Error         No Injury
# 301715     Near office complex     Human Error         No Injury
# 301716               Open area     Human Error         No Injury
#
#         Junction Control     Road_Character               Road_Type  \
# 0       No signal lights             Others  Highways & Expressways
# 1         Not Applicable     Not Applicable  Highways & Expressways
# 2           Uncontrolled             Others  Highways & Expressways
# 3             Controlled     Not Applicable  Highways & Expressways
# 5         Not Applicable     Not Applicable  Highways & Expressways
# ...                  ...                ...                     ...
# 301709    Not Applicable  Straight and flat             Urban Roads
# 301710    Not Applicable     Not Applicable  Highways & Expressways
# 301714  Not at  Junction  Straight and flat  Highways & Expressways
# 301715      Uncontrolled             Others  Highways & Expressways
# 301716    Not Applicable  Straight and flat  Highways & Expressways
#
#           Surface_Type Surface_Condition            Road_Condition  \
# 0         Bitumen(Tar)               Dry  No influence on accident
# 1       Not Applicable               Wet  No influence on accident
# 2         Bitumen(Tar)               Dry  No influence on accident
# 3         Bitumen(Tar)               Wet  No influence on accident
# 5       Not Applicable               Wet  No influence on accident
# ...                ...               ...                       ...
# 301709        Concrete               Dry  No influence on accident
# 301710    Bitumen(Tar)               Dry  No influence on accident
# 301714        Concrete               Dry  No influence on accident
# 301715        Concrete               Dry  No influence on accident
# 301716        Concrete               Dry  No influence on accident
#
#        Weather Condition Lane_Type
# 0                  Clear       NaN
# 1           Rain / Windy       NaN
# 2                  Clear       NaN
# 3                 Clear        NaN
# 5                 Clear        NaN
# ...                  ...       ...
# 301709            Clear        NaN
# 301710            Clear        NaN
# 301714            Clear        NaN
# 301715      Rain / Windy       NaN
# 301716            Clear        NaN
#
# [239215 rows x 20 columns]

# %%
data_cleaned = data.dropna()
data_cleaned.head()
# Out:
#      District Name  Year        Date Time of Day  Number of vehicles involved  \
# 4           Hassan  2020  03-08-2020       Night                            2
# 8   Bengaluru City  2018  27-09-2018       Night                            2
# 45      Ramanagara  2022  26-03-2022       Night                            2
# 51        Tumakuru  2022  08-04-2022   Afternoon                            2
# 52        Tumakuru  2016  24-01-2016   Afternoon                            2
#
#     Number of Casualties Accident_Classification Accident_Spot Urban / Rural  \
# 4                     10          Road Accidents   Cross roads         Rural
# 8                     10          Road Accidents         Other         Urban
# 45                    10          Not Applicable        Curves         Rural
# 51                    10          Road Accidents   Narrow road         Rural
# 52                    10          Road Accidents        Bridge         Urban
#
#                  Accident Location           Cause Accident Severity  \
# 4   Near a factory industrial area  Not Applicable             Fatal
# 8                        Open area     Human Error             Fatal
# 45                       Open area  Not Applicable             Fatal
# 51  Near a factory industrial area     Human Error             Fatal
# 52       Narrow bridge or culverts     Human Error             Fatal
#
#    Junction Control     Road_Character               Road_Type  \
# 4      Uncontrolled  Straight and flat  Highways & Expressways
# 8     Signal Lights     Not Applicable  Highways & Expressways
# 45   Not Applicable              Curve  Highways & Expressways
# 51   Not Applicable     Not Applicable  Highways & Expressways
# 52       Controlled             Others  Highways & Expressways
#
#       Surface_Type Surface_Condition            Road_Condition  \
# 4         Concrete               Wet  No influence on accident
# 8     Bitumen(Tar)               Dry  No influence on accident
# 45  Not Applicable               Dry  No influence on accident
# 51    Bitumen(Tar)               Dry  No influence on accident
# 52    Bitumen(Tar)               Dry  No influence on accident
#
#    Weather Condition   Lane_Type
# 4       Rain / Windy    DualLane
# 8             Clear     DualLane
# 45      Rain / Windy      Others
# 51             Clear  SingleLane
# 52            Clear   SingleLane

# %%
print(data_cleaned.isnull().values.any())
# Out:
# False

# %%
duplicates = data_cleaned[data_cleaned.duplicated()]
print(duplicates)
print()
print(data.duplicated().sum())
# Out:
#            District Name  Year        Date Time of Day  \
# 86469         Shivamogga  2022  28-04-2022       Night
# 115018            Hassan  2018  20-07-2018     Evening
# 203256  Dakshina Kannada  2023  21-04-2023     Evening
#
#         Number of vehicles involved  Number of Casualties  \
# 86469                             2                     2
# 115018                            1                     1
# 203256                            2                     2
#
#        Accident_Classification   Accident_Spot Urban / Rural  \
# 86469           Road Accidents  Not Applicable         Urban
# 115018          Road Accidents           Other         Rural
# 203256          Road Accidents  Not Applicable         Rural
#
#        Accident Location        Cause Accident Severity  Junction Control  \
# 86469      Near Hospital  Human Error           Serious      Uncontrolled
# 115018         Open area  Human Error           Serious  Not at  Junction
# 203256         Open area  Human Error            Slight  Not at  Junction
#
#            Road_Character               Road_Type  Surface_Type  \
# 86469   Straight and flat  Highways & Expressways  Bitumen(Tar)
# 115018  Straight and flat             Rural Roads  Bitumen(Tar)
# 203256  Straight and flat  Highways & Expressways  Bitumen(Tar)
#
#        Surface_Condition            Road_Condition Weather Condition  \
# 86469                Dry  No influence on accident             Clear
# 115018               Dry  No influence on accident            Clear
# 203256               Dry  No influence on accident             Clear
#
#          Lane_Type
# 86469     DualLane
# 115018  SingleLane
# 203256    DualLane
#
# 41

# %%
data_cleaned = data_cleaned.drop_duplicates()
data_cleaned.head()
# Out:
#      District Name  Year        Date Time of Day  Number of vehicles involved  \
# 4           Hassan  2020  03-08-2020       Night                            2
# 8   Bengaluru City  2018  27-09-2018       Night                            2
# 45      Ramanagara  2022  26-03-2022       Night                            2
# 51        Tumakuru  2022  08-04-2022   Afternoon                            2
# 52        Tumakuru  2016  24-01-2016   Afternoon                            2
#
#     Number of Casualties Accident_Classification Accident_Spot Urban / Rural  \
# 4                     10          Road Accidents   Cross roads         Rural
# 8                     10          Road Accidents         Other         Urban
# 45                    10          Not Applicable        Curves         Rural
# 51                    10          Road Accidents   Narrow road         Rural
# 52                    10          Road Accidents        Bridge         Urban
#
#                  Accident Location           Cause Accident Severity  \
# 4   Near a factory industrial area  Not Applicable             Fatal
# 8                        Open area     Human Error             Fatal
# 45                       Open area  Not Applicable             Fatal
# 51  Near a factory industrial area     Human Error             Fatal
# 52       Narrow bridge or culverts     Human Error             Fatal
#
#    Junction Control     Road_Character               Road_Type  \
# 4      Uncontrolled  Straight and flat  Highways & Expressways
# 8     Signal Lights     Not Applicable  Highways & Expressways
# 45   Not Applicable              Curve  Highways & Expressways
# 51   Not Applicable     Not Applicable  Highways & Expressways
# 52       Controlled             Others  Highways & Expressways
#
#       Surface_Type Surface_Condition            Road_Condition  \
# 4         Concrete               Wet  No influence on accident
# 8     Bitumen(Tar)               Dry  No influence on accident
# 45  Not Applicable               Dry  No influence on accident
# 51    Bitumen(Tar)               Dry  No influence on accident
# 52    Bitumen(Tar)               Dry  No influence on accident
#
#    Weather Condition   Lane_Type
# 4       Rain / Windy    DualLane
# 8             Clear     DualLane
# 45      Rain / Windy      Others
# 51             Clear  SingleLane
# 52            Clear   SingleLane

# %%
data_cleaned.duplicated().sum()
# Out:
# np.int64(0)

# %%
def clean_text(text):
    if isinstance(text, str):
        return text.strip().title()
    return text

columns_to_clean = [
    'District Name', 'Accident_Classification', 'Accident_Spot',
    'Urban / Rural', 'Accident Location', 'Cause', 'Accident Severity',
    'Junction Control', 'Road_Character', 'Road_Type', 'Surface_Type',
    'Surface_Condition', 'Road_Condition', 'Weather Condition', 'Lane_Type'
]

for col in columns_to_clean:
    data_cleaned[col] = data_cleaned[col].apply(clean_text)

for col in columns_to_clean:
    print(f"Unique values in {col}:")
    print(data_cleaned[col].unique())
    print("\n")
# Out:
# Unique values in District Name:
# ['Hassan' 'Bengaluru City' 'Ramanagara' 'Tumakuru' 'Bagalkot'
#  'Chikkamagaluru' 'Hubballi Dharwad City' 'Kalaburagi' 'Udupi'
#  'Bengaluru Dist' 'Belagavi Dist' 'Karnataka Railways' 'Chitradurga'
#  'Mangaluru City' 'Mysuru City' 'Uttara Kannada' 'Vijayapur' 'Mandya'
#  'Raichur' 'Shivamogga' 'Kolar' 'Mysuru Dist' 'Haveri' 'Ballari'
#  'Chamarajanagar' 'Davanagere' 'Kodagu' 'Bidar' 'Dharwad' 'Belagavi City'
#  'Dakshina Kannada' 'Chickballapura' 'K.G.F' 'Gadag' 'Koppal'
#  'Vijayanagara' 'Kalaburagi City' 'Yadgir']
#
#
# Unique values in Accident_Classification:
# ['Road Accidents' 'Not Applicable' 'Rail Road Accidents'
#  'Other Railway Accidents']
#
#
# Unique values in Accident_Spot:
# ['Cross Roads' 'Other' 'Curves' 'Narrow Road' 'Bridge' 'Not Applicable'
#  'Circle' 'Junction' 'Road Hump Or Rumble Strips' 'Culvert' 'Offset'
#  'T Junction' 'Bottleneck' 'More Than Four Arms' 'Y Junction'
#  'Railway Crossing' 'Rail Crossing Manned' 'Round About Or Circle'
#  'Staggered Junction' 'Rail Crossing Unmanned']
#
#
# Unique values in Urban / Rural:
# ['Rural' 'Urban' 'Not Applicable']
#
#
# Unique values in Accident Location:
# ['Near A Factory Industrial Area' 'Open Area' 'Narrow Bridge Or Culverts'
#  'Near Or Inside A Village' 'Near School Or College'
#  'At Pedestrian Crossing' 'Residential Area' 'Near Office Complex'
#  'Near Hospital' 'Near Petrol Pump' 'In Bazaar' 'Near Bus Stop'
#  'Near A Religious Place' 'Affected By Encroachments'
#  'Near A Recreation Place/Cinema']
#
#
# Unique values in Cause:
# ['Not Applicable' 'Human Error' 'Vehicle Defect' 'Road Environment Defect']
#
#
# Unique values in Accident Severity:
# ['Fatal' 'Serious' 'Slight' 'No Injury']
#
#
# Unique values in Junction Control:
# ['Uncontrolled' 'Signal Lights' 'Not Applicable' 'Controlled'
#  'Not At  Junction' 'Police / Manual' 'No Signal Lights' 'Stop Sign']
#
#
# Unique values in Road_Character:
# ['Straight And Flat' 'Not Applicable' 'Curve' 'Others' 'Inclined'
#  'Slight Curve' 'Steep / Incline']
#
#
# Unique values in Road_Type:
# ['Highways & Expressways' 'Rural Roads' 'Urban Roads' 'Not Applicable']
#
#
# Unique values in Surface_Type:
# ['Concrete' 'Bitumen(Tar)' 'Not Applicable' 'Metalled' 'Surfaced' 'Kutcha'
#  'Gravel']
#
#
# Unique values in Surface_Condition:
# ['Wet' 'Dry' 'Ditch Or Potholed']
#
#
# Unique values in Road_Condition:
# ['No Influence On Accident' 'Construction Work / Material' 'Pot Holed'
#  'Engineering Defect Of Road' 'Drainage Ditch']
#
#
# Unique values in Weather Condition:
# ['Rain / Windy' 'Clear' 'Cloudy' 'Fog / Mist' 'Mist Or Fog']
#
#
# Unique values in Lane_Type:
# ['Duallane' 'Others' 'Singlelane' 'Fourlane' 'Sixlane']

# %%
data_cleaned = data_cleaned.replace(
    to_replace=r'(?i)\bnot applicable\b',  # regex: case-insensitive match
    value='NA',
    regex=True
)

# Step 2: Convert all 'NA' values to np.nan
data_cleaned.replace('NA', np.nan, inplace=True)

# Step 3: Drop rows with any null value
data_cleaned.dropna(inplace=True)

# Optional: Reset index after dropping
data_cleaned.reset_index(drop=True, inplace=True)

print("Cleaned dataset shape:", data_cleaned.shape)
# Out:
# Cleaned dataset shape: (28788, 20)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Count top 5 districts with most accidents
top_districts = data_cleaned['District Name'].value_counts().head(5)

# Plot
plt.figure(figsize=(8,5))
sns.barplot(x=top_districts.values, y=top_districts.index, palette='mako')
plt.title('Top 5 Districts by Number of Accidents')
plt.xlabel('Number of Accidents')
plt.ylabel('District')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Soumashree\AppData\Local\Temp\ipykernel_20512\1232155895.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x=top_districts.values, y=top_districts.index, palette='mako')

# %%
severity_counts = data_cleaned['Accident Severity'].value_counts()

plt.figure(figsize=(6,6))
plt.pie(severity_counts, labels=severity_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Accident Severity Distribution')
plt.axis('equal')
plt.show()

# %%
data_cleaned.to_csv('cleaned_data.csv', index=False)

# %%
df = pd.read_csv("cleaned_data.csv")

# %%
df.head()
# Out:
#     District Name  Year        Date Time of Day  Number of vehicles involved  \
# 0        Tumakuru  2016  24-01-2016   Afternoon                            2
# 1          Hassan  2016  02-09-2016       Night                            1
# 2  Bengaluru Dist  2019  27-11-2019       Night                            1
# 3     Chitradurga  2017  12-09-2017       Night                            1
# 4         Raichur  2017  12-07-2017     Evening                            2
#
#    Number of Casualties Accident_Classification Accident_Spot Urban / Rural  \
# 0                    10          Road Accidents        Bridge         Urban
# 1                    10          Road Accidents         Other         Rural
# 2                    10          Road Accidents      Junction         Urban
# 3                     9          Road Accidents         Other         Urban
# 4                     8          Road Accidents         Other         Urban
#
#            Accident Location        Cause Accident Severity Junction Control  \
# 0  Narrow Bridge Or Culverts  Human Error             Fatal       Controlled
# 1     At Pedestrian Crossing  Human Error             Fatal     Uncontrolled
# 2     Near School Or College  Human Error             Fatal       Controlled
# 3                  Open Area  Human Error             Fatal     Uncontrolled
# 4           Near Petrol Pump  Human Error             Fatal     Uncontrolled
#
#       Road_Character               Road_Type  Surface_Type Surface_Condition  \
# 0             Others  Highways & Expressways  Bitumen(Tar)               Dry
# 1  Straight And Flat  Highways & Expressways  Bitumen(Tar)               Dry
# 2  Straight And Flat  Highways & Expressways      Concrete               Dry
# 3             Others  Highways & Expressways  Bitumen(Tar)               Dry
# 4             Others             Urban Roads  Bitumen(Tar)               Wet
#
#                  Road_Condition Weather Condition   Lane_Type
# 0      No Influence On Accident             Clear  Singlelane
# 1      No Influence On Accident             Clear    Duallane
# 2  Construction Work / Material             Clear      Others
# 3      No Influence On Accident             Clear      Others
# 4                     Pot Holed             Clear      Others

# %%
df['Date'] = pd.to_datetime(df['Date'])
df['Day of Week'] = df['Date'].dt.day_name()

# Optional: order Time of Day and Day of Week
time_order = ['Morning', 'Afternoon', 'Evening', 'Night']
day_order = ['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']

# Group by Time of Day and Day of Week to count accidents
grouped = df.groupby(['Time of Day', 'Day of Week']).size().reset_index(name='Accidents')

# Pivot for heatmap
pivot_df = grouped.pivot(index='Time of Day', columns='Day of Week', values='Accidents')
pivot_df = pivot_df.reindex(index=time_order, columns=day_order)

# Plot heatmap
plt.figure(figsize=(12, 6))
sns.heatmap(pivot_df, annot=True, cmap='YlGnBu', fmt='d')
plt.title('Accident Patterns by Time of Day and Day of Week', fontsize=14)
plt.xlabel('Day of Week')
plt.ylabel('Time of Day')
plt.show()

# Weekday vs Weekend classification
df['Weekend'] = df['Day of Week'].isin(['Saturday', 'Sunday'])

# Group and count for barplot
weekend_grouped = df.groupby(['Weekend', 'Time of Day']).size().reset_index(name='Accidents')

# Plot bar chart
plt.figure(figsize=(10, 5))
sns.barplot(data=weekend_grouped, x='Time of Day', y='Accidents', hue='Weekend', order=time_order)
plt.title('Weekday vs Weekend Accidents by Time of Day', fontsize=14)
plt.xlabel('Time of Day')
plt.ylabel('Number of Accidents')
plt.legend(title='Weekend', labels=['Weekday', 'Weekend'])
plt.show()
# Out:
# C:\Users\TANISHA MANNA\AppData\Local\Temp\ipykernel_29416\2895091512.py:1: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   df['Date'] = pd.to_datetime(df['Date'])

# %%
road_type_counts = df['Road_Type'].value_counts().reset_index()
road_type_counts.columns = ['Road Type', 'Accident Count']

# Plotting the bar chart
plt.figure(figsize=(12, 6))
sns.barplot(data=road_type_counts, y='Road Type', x='Accident Count', palette='viridis')
plt.title('Road Type Contribution to Accidents', fontsize=14)
plt.xlabel('Number of Accidents')
plt.ylabel('Road Type')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\TANISHA MANNA\AppData\Local\Temp\ipykernel_29416\326173743.py:6: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=road_type_counts, y='Road Type', x='Accident Count', palette='viridis')

# %%
weather_casualties = data_cleaned.groupby('Weather Condition')['Number of Casualties'].sum().sort_values(ascending=False)

# Plot
plt.figure(figsize=(8,5))
sns.barplot(x=weather_casualties.values, y=weather_casualties.index, palette='coolwarm')
plt.title('Casualties by Weather Conditions')
plt.xlabel('Total Number of Casualties')
plt.ylabel('Weather Condition')
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 weather_casualties = data_cleaned.groupby('Weather Condition')['Number of Casualties'].sum().sort_values(ascending=False)
#       3 # Plot
#       4 plt.figure(figsize=(8,5))
#
# NameError: name 'data_cleaned' is not defined
